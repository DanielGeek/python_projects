# %% [markdown]
# ## MLFlow Tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check localhost connection")

with mlflow.start_run():
    mlflow.log_metric("test", 1)
    mlflow.log_metric("Daniel", 2)
# Out:
# 🏃 View run delightful-hawk-703 at: http://127.0.0.1:5000/#/experiments/1/runs/de8ba71ef39c4470b5c151a3d09661a4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test1", 1)
    mlflow.log_metric("Daniel1", 2)
# Out:
# 🏃 View run delicate-shark-379 at: http://127.0.0.1:5000/#/experiments/1/runs/14980c52a8414aa59e2721bf25d72972
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test2", 1)
    mlflow.log_metric("Daniel2", 2)
# Out:
# 🏃 View run redolent-conch-534 at: http://127.0.0.1:5000/#/experiments/1/runs/bc59c70d54084fcb82ff07cf1d48c4f7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
